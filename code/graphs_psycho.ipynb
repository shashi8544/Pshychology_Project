# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = pd.read_csv('survey.csv')

# %%
dic = dataset.to_dict()

# %%
dataset.columns
# Out:
# Index(['Age', 'Gender', 'Ayear', 'scl_med_t', 'free_time', 'frnd_prsnl',
#        'scl_sprt_v_prsnl', 'scl_spc_cnt_ppl', 'scl_md_lmt', 'scl_md_mt_frn',
#        'pref_talk', 'Othr_pst', 'Oth_lkd_wshd', 'scl_md_jn', 'I_or_E',
#        'scl_md_C19', 'scl_md_1', 'scl_md_2', 'scl_md_3', 'scl_md_4',
#        'scl_md_5', 'scl_md_6', 'scl_md_ol', 'lnl_1', 'lnl_2', 'lnl_3', 'lnl_4',
#        'lnl_5', 'lnl_6', 'lnl_7', 'lnl_8', 'lnl_9', 'lnl_10', 'lnl_11',
#        'lnl_12', 'lnl_13', 'lnl_14', 'lnl_15', 'lnl_16', 'lnl_17', 'lnl_18',
#        'lnl_19', 'lnl_20', 'lnl_ol', 'compuls'],
#       dtype='object')

# %%
res_scl_avg_lnl_md = {'0-2.5':0,'2.5-5':0,'5-7.5':0,'7.5-9.5':0}
res_scl_avg_lnl_md_cnt = {'0-2.5':0,'2.5-5':0,'5-7.5':0,'7.5-9.5':0}
dic_comp ={'0-2.5':0,'2.5-5':0,'5-7.5':0,'7.5-9.5':0}
i = 0
for items in dataset['compuls']:
  if(items==0 or items==0.5 or items==1 or items==1.5 or items==2 or items==2.5):
    dic_comp['0-2.5']+=1;
    res_scl_avg_lnl_md_cnt['0-2.5'] +=1;
    res_scl_avg_lnl_md['0-2.5'] +=dic['lnl_ol'][i];
    i =i+1
  if(items==3 or items==3.5 or items==4 or items==4.5 or items==5):
    dic_comp['2.5-5']+=1;
    res_scl_avg_lnl_md_cnt['2.5-5'] +=1;
    res_scl_avg_lnl_md['2.5-5'] +=dic['lnl_ol'][i];
    i =i+1
  if(items==5.5 or items==6 or items==6.5 or items==7 or items==7.5 ):
    dic_comp['5-7.5']+=1;
    res_scl_avg_lnl_md_cnt['5-7.5'] +=1;
    res_scl_avg_lnl_md['5-7.5'] +=dic['lnl_ol'][i];
    i =i+1
  if(items==8 or items==8.5 or items==9 or items==9.5):
    dic_comp['7.5-9.5']+=1;
    res_scl_avg_lnl_md_cnt['7.5-9.5'] +=1;
    res_scl_avg_lnl_md['7.5-9.5'] +=dic['lnl_ol'][i];
    i =i+1
res_scl_avg_lnl_md['0-2.5'] = round(res_scl_avg_lnl_md['0-2.5']/res_scl_avg_lnl_md_cnt['0-2.5'])
res_scl_avg_lnl_md['2.5-5'] = round(res_scl_avg_lnl_md['2.5-5']/res_scl_avg_lnl_md_cnt['2.5-5'])
res_scl_avg_lnl_md['5-7.5'] = round(res_scl_avg_lnl_md['5-7.5']/res_scl_avg_lnl_md_cnt['5-7.5'])
res_scl_avg_lnl_md['7.5-9.5'] = round(res_scl_avg_lnl_md['7.5-9.5']/res_scl_avg_lnl_md_cnt['7.5-9.5'])
plt.figure(figsize=(5,5))
plt.bar(res_scl_avg_lnl_md.keys(), res_scl_avg_lnl_md.values(), width=.3, color='orange')
plt.title("Plot of Avg Loneliness vs Compulsive Use")
plt.xlabel("Compulsive Use (in Hours)")
plt.ylabel("Average Loneliness")
plt.figure(figsize=(5,5))
plt.bar(res_scl_avg_lnl_md_cnt.keys(), res_scl_avg_lnl_md_cnt.values(), width=.3, color='orange')
plt.title("Plot of Avg Loneliness vs Compulsive Use")
plt.xlabel("Compulsive Use (in Hours)")
plt.ylabel("Frequency of Compulsive Use")
plt.figure(figsize=(5,5))
labels = '0-2.5 hours','2-5 - 5 hours','5-7.5 hours','7.5 - 9.5 hours'
sections = [dic_comp['0-2.5'],dic_comp['2.5-5'],dic_comp['5-7.5'],dic_comp['7.5-9.5']]
colors = ['c', 'g','r','b']
plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0.1, 0.1,0.1,0.1),
        autopct = '%1.2f%%')
# plt.axis('equal') 
plt.title('Compulsive Use')
plt.show()

# %%
dic_comp ={'0-2.5':0,'2.5-5':0,'5-7.5':0,'7.5-9.5':0}
for items in dataset['compuls']:
  if(items==0 or items==0.5 or items==1 or items==1.5 or items==2 or items==2.5):
    dic_comp['0-2.5']+=1;
  if(items==3 or items==3.5 or items==4 or items==4.5 or items==5):
    dic_comp['2.5-5']+=1;
  if(items==5.5 or items==6 or items==6.5 or items==7 or items==7.5 ):
    dic_comp['5-7.5']+=1;
  if(items==8 or items==8.5 or items==9 or items==9.5):
    dic_comp['7.5-9.5']+=1;
plt.figure(figsize=(5,5))
labels = '0-2.5 hours','2-5 - 5 hours','5-7.5 hours','7.5 - 9.5 hours'
sections = [dic_comp['0-2.5'],dic_comp['2.5-5'],dic_comp['5-7.5'],dic_comp['7.5-9.5']]
colors = ['c', 'g','r','b']
plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0.1, 0.1,0.1,0.1),
        autopct = '%1.2f%%')
plt.title('Compulsive Use')
plt.show()

# %%
dic_comp ={'0-2.5':0,'2.5-5':0,'5-7.5':0,'7.5-9.5':0}
for items in dataset['compuls']:
  if(items==0 or items==0.5 or items==1 or items==1.5 or items==2 or items==2.5):
    dic_comp['0-2.5']+=1;
  if(items==3 or items==3.5 or items==4 or items==4.5 or items==5):
    dic_comp['2.5-5']+=1;
  if(items==5.5 or items==6 or items==6.5 or items==7 or items==7.5 ):
    dic_comp['5-7.5']+=1;
  if(items==8 or items==8.5 or items==9 or items==9.5):
    dic_comp['7.5-9.5']+=1;
plt.figure(figsize=(5,5))
labels = '0-2.5 hours','2-5 - 5 hours','5-7.5 hours','7.5 - 9.5 hours'
sections = [dic_comp['0-2.5'],dic_comp['2.5-5'],dic_comp['5-7.5'],dic_comp['7.5-9.5']]
colors = ['c', 'g','r','b']
plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0.1, 0.1,0.1,0.1),
        autopct = '%1.2f%%')
# plt.axis('equal') 
plt.title('Compulsive Use')
plt.show()

# %%
dic_comp ={'0-2.5':0,'2.5-5':0,'5-7.5':0,'7.5-9.5':0}
for items in dataset['compuls']:
  if(items==0 or items==0.5 or items==1 or items==1.5 or items==2 or items==2.5):
    dic_comp['0-2.5']+=1;
  if(items==3 or items==3.5 or items==4 or items==4.5 or items==5):
    dic_comp['2.5-5']+=1;
  if(items==5.5 or items==6 or items==6.5 or items==7 or items==7.5 ):
    dic_comp['5-7.5']+=1;
  if(items==8 or items==8.5 or items==9 or items==9.5):
    dic_comp['7.5-9.5']+=1;
plt.figure(figsize=(5,5))
labels = '0-2.5 hours','2-5 - 5 hours','5-7.5 hours','7.5 - 9.5 hours'
sections = [dic_comp['0-2.5'],dic_comp['2.5-5'],dic_comp['5-7.5'],dic_comp['7.5-9.5']]
colors = ['c', 'g','r','b']
plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0.1, 0.1,0.1,0.1),
        autopct = '%1.2f%%')
# plt.axis('equal') 
plt.title('Compulsive Use')
plt.show()

# %%
myqueries = {
    1:'compuls',
    2:'compuls',
    3:'compuls',
    4:'compuls'
}
cnt1 = 0
cnt2 = 0
cnt3 = 0
cnt4 = 0
res_lnl_avg_scl_md = {'0-20':0,'21-40':0,'41-60':0,'61-80':0}
res_lnl_avg_scl_md_cnt = {'0-20':0,'21-40':0,'41-60':0,'61-80':0}
for x,y in myqueries.items():
  for i in dic['lnl_ol']:
    if(dic[y][i]==x):
      if(x==1):
        cnt1 +=1;
      if(x==2):
        cnt2 +=1;
      if(x==3):
        cnt3 +=1;
      if(x==4):
        cnt4 +=1;
plt.figure(figsize=(5,5))
labels = '0-2.5 hours','2-5 - 5 hours','5-7.5 hours','7.5 - 9.5 hours'
sections = [cnt1,cnt2,cnt3,cnt4]
colors = ['c', 'g','r','b']
plt.pie(sections, labels=labels, colors=colors,
        startangle=90,
        explode = (0.1, 0.1,0.1,0.1),
        autopct = '%1.2f%%')
# plt.axis('equal') 
plt.title('Gender')
plt.show()

# %%
myq1 = {
    0:'I_or_E',
    1:'I_or_E'
}
myq2 = {
    1:'scl_med_t',
    2:'scl_med_t',
    3:'scl_med_t',
    4:'scl_med_t'
}

for x,y in myq1.items():
  res_lnl_avg_scl_md = {'0-20':0,'21-40':0,'41-60':0,'61-80':0}
  res_lnl_avg_scl_md_cnt = {'0-20':0,'21-40':0,'41-60':0,'61-80':0}
  # for p,q in myq2.items():
  for i in dic['lnl_ol']:
    if(dic[y][i]==x):
      if(dic['lnl_ol'][i]>=0 and dic['lnl_ol'][i]<=20):
        res_lnl_avg_scl_md_cnt['0-20'] +=1;
        res_lnl_avg_scl_md['0-20'] +=dic['scl_md_ol'][i];
      if(dic['lnl_ol'][i]>=21 and dic['lnl_ol'][i]<=40):
        res_lnl_avg_scl_md_cnt['21-40'] +=1;
        res_lnl_avg_scl_md['21-40'] +=dic['scl_md_ol'][i];
      if(dic['lnl_ol'][i]>=41 and dic['lnl_ol'][i]<=60):
        res_lnl_avg_scl_md_cnt['41-60'] +=1;
        res_lnl_avg_scl_md['41-60'] +=dic['scl_md_ol'][i];
      if(dic['lnl_ol'][i]>=61 and dic['lnl_ol'][i]<=80):
        res_lnl_avg_scl_md_cnt['61-80'] +=1;
        res_lnl_avg_scl_md['61-80'] +=dic['scl_md_ol'][i];
  print(res_lnl_avg_scl_md)
  print(res_lnl_avg_scl_md_cnt)
  print(res_lnl_avg_scl_md)
  plt.figure(figsize=(5,5))
  # res_lnl_avg_scl_md_cnt['0-20'] = res_lnl_avg_scl_md_cnt['0-20']*100/(res_lnl_avg_scl_md_cnt['21-40']+res_lnl_avg_scl_md_cnt['41-60']+res_lnl_avg_scl_md_cnt['61-80']+res_lnl_avg_scl_md_cnt['0-20'])
  # res_lnl_avg_scl_md_cnt['21-40'] = res_lnl_avg_scl_md_cnt['21-40']*100/(res_lnl_avg_scl_md_cnt['21-40']+res_lnl_avg_scl_md_cnt['41-60']+res_lnl_avg_scl_md_cnt['61-80']+res_lnl_avg_scl_md_cnt['0-20'])
  # res_lnl_avg_scl_md_cnt['41-60'] = res_lnl_avg_scl_md_cnt['41-60']*100/(res_lnl_avg_scl_md_cnt['21-40']+res_lnl_avg_scl_md_cnt['41-60']+res_lnl_avg_scl_md_cnt['61-80']+res_lnl_avg_scl_md_cnt['0-20'])
  # res_lnl_avg_scl_md_cnt['61-80'] = res_lnl_avg_scl_md_cnt['61-80']*100/(res_lnl_avg_scl_md_cnt['21-40']+res_lnl_avg_scl_md_cnt['41-60']+res_lnl_avg_scl_md_cnt['61-80']+res_lnl_avg_scl_md_cnt['0-20'])
  plt.bar(res_lnl_avg_scl_md_cnt.keys(), res_lnl_avg_scl_md_cnt.values(), width=.3, color='blue')
  if(x==0):
    plt.title("introvert")
  else:
    plt.title("Extrovert")
  plt.xlabel("Loneliness Scale")
  plt.ylabel("Frequency")
# Out:
# {'0-20': 0, '21-40': 585, '41-60': 2129, '61-80': 211}
# {'0-20': 0, '21-40': 49, '41-60': 148, '61-80': 14}
# {'0-20': 0, '21-40': 585, '41-60': 2129, '61-80': 211}
# {'0-20': 6, '21-40': 395, '41-60': 1039, '61-80': 85}
# {'0-20': 1, '21-40': 36, '41-60': 72, '61-80': 5}
# {'0-20': 6, '21-40': 395, '41-60': 1039, '61-80': 85}

# %%
myq2 = {
    1:'scl_med_t',
    2:'scl_med_t',
    3:'scl_med_t',
    4:'scl_med_t'
}


for p,q in myq2.items():
  res_lnl_avg_scl_md = {'0-20':0,'21-40':0,'41-60':0,'61-80':0}
  res_lnl_avg_scl_md_cnt = {'0-20':0,'21-40':0,'41-60':0,'61-80':0}
  for i in dic['lnl_ol']:
    if(dic[y][i]==x and dic[q][i]==p):
      if(dic['lnl_ol'][i]>=0 and dic['lnl_ol'][i]<=20):
        res_lnl_avg_scl_md_cnt['0-20'] +=1;
        res_lnl_avg_scl_md['0-20'] +=dic['scl_md_ol'][i];
      if(dic['lnl_ol'][i]>=21 and dic['lnl_ol'][i]<=40):
        res_lnl_avg_scl_md_cnt['21-40'] +=1;
        res_lnl_avg_scl_md['21-40'] +=dic['scl_md_ol'][i];
      if(dic['lnl_ol'][i]>=41 and dic['lnl_ol'][i]<=60):
        res_lnl_avg_scl_md_cnt['41-60'] +=1;
        res_lnl_avg_scl_md['41-60'] +=dic['scl_md_ol'][i];
      if(dic['lnl_ol'][i]>=61 and dic['lnl_ol'][i]<=80):
        res_lnl_avg_scl_md_cnt['61-80'] +=1;
        res_lnl_avg_scl_md['61-80'] +=dic['scl_md_ol'][i];
  print(res_lnl_avg_scl_md)
  print(res_lnl_avg_scl_md_cnt)
  print(res_lnl_avg_scl_md)
  plt.figure(figsize=(5,5))
  res_lnl_avg_scl_md_cnt['0-20'] = res_lnl_avg_scl_md_cnt['0-20']*100/(res_lnl_avg_scl_md_cnt['21-40']+res_lnl_avg_scl_md_cnt['41-60']+res_lnl_avg_scl_md_cnt['61-80']+res_lnl_avg_scl_md_cnt['0-20'])
  res_lnl_avg_scl_md_cnt['21-40'] = res_lnl_avg_scl_md_cnt['21-40']*100/(res_lnl_avg_scl_md_cnt['21-40']+res_lnl_avg_scl_md_cnt['41-60']+res_lnl_avg_scl_md_cnt['61-80']+res_lnl_avg_scl_md_cnt['0-20'])
  res_lnl_avg_scl_md_cnt['41-60'] = res_lnl_avg_scl_md_cnt['41-60']*100/(res_lnl_avg_scl_md_cnt['21-40']+res_lnl_avg_scl_md_cnt['41-60']+res_lnl_avg_scl_md_cnt['61-80']+res_lnl_avg_scl_md_cnt['0-20'])
  res_lnl_avg_scl_md_cnt['61-80'] = res_lnl_avg_scl_md_cnt['61-80']*100/(res_lnl_avg_scl_md_cnt['21-40']+res_lnl_avg_scl_md_cnt['41-60']+res_lnl_avg_scl_md_cnt['61-80']+res_lnl_avg_scl_md_cnt['0-20'])
  plt.bar(res_lnl_avg_scl_md_cnt.keys(), res_lnl_avg_scl_md_cnt.values(), width=.3, color='blue')
  plt.title("{}-{} hour".format(2*(p-1),2*p))
  plt.xlabel("Loneliness Scale")
  plt.ylabel("z")
# Out:
# {'0-20': 0, '21-40': 219, '41-60': 482, '61-80': 31}
# {'0-20': 0, '21-40': 22, '41-60': 36, '61-80': 2}
# {'0-20': 0, '21-40': 219, '41-60': 482, '61-80': 31}
# {'0-20': 0, '21-40': 35, '41-60': 121, '61-80': 0}
# {'0-20': 0, '21-40': 3, '41-60': 8, '61-80': 0}
# {'0-20': 0, '21-40': 35, '41-60': 121, '61-80': 0}
# {'0-20': 0, '21-40': 115, '41-60': 246, '61-80': 0}
# {'0-20': 0, '21-40': 9, '41-60': 16, '61-80': 0}
# {'0-20': 0, '21-40': 115, '41-60': 246, '61-80': 0}
# {'0-20': 6, '21-40': 26, '41-60': 151, '61-80': 54}
# {'0-20': 1, '21-40': 2, '41-60': 10, '61-80': 3}
# {'0-20': 6, '21-40': 26, '41-60': 151, '61-80': 54}

# %%
myq1 = {
    0:'I_or_E',
    1:'I_or_E'
}
myq2 = {
    1:'scl_med_t',
    2:'scl_med_t',
    3:'scl_med_t',
    4:'scl_med_t'
}

for x,y in myq1.items():
  for p,q in myq2.items():
    res_lnl_avg_scl_md = {'0-20':0,'21-40':0,'41-60':0,'61-80':0}
    res_lnl_avg_scl_md_cnt = {'0-20':0,'21-40':0,'41-60':0,'61-80':0}
    for i in dic['lnl_ol']:
      if(dic[y][i]==x and dic[q][i]==p):
        if(dic['lnl_ol'][i]>=0 and dic['lnl_ol'][i]<=20):
          res_lnl_avg_scl_md_cnt['0-20'] +=1;
          res_lnl_avg_scl_md['0-20'] +=dic['scl_md_ol'][i];
        if(dic['lnl_ol'][i]>=21 and dic['lnl_ol'][i]<=40):
          res_lnl_avg_scl_md_cnt['21-40'] +=1;
          res_lnl_avg_scl_md['21-40'] +=dic['scl_md_ol'][i];
        if(dic['lnl_ol'][i]>=41 and dic['lnl_ol'][i]<=60):
          res_lnl_avg_scl_md_cnt['41-60'] +=1;
          res_lnl_avg_scl_md['41-60'] +=dic['scl_md_ol'][i];
        if(dic['lnl_ol'][i]>=61 and dic['lnl_ol'][i]<=80):
          res_lnl_avg_scl_md_cnt['61-80'] +=1;
          res_lnl_avg_scl_md['61-80'] +=dic['scl_md_ol'][i];
    print(res_lnl_avg_scl_md)
    print(res_lnl_avg_scl_md_cnt)
    print(res_lnl_avg_scl_md)
    plt.figure(figsize=(5,5))
    # res_lnl_avg_scl_md_cnt['0-20'] = res_lnl_avg_scl_md_cnt['0-20']*100/(res_lnl_avg_scl_md_cnt['21-40']+res_lnl_avg_scl_md_cnt['41-60']+res_lnl_avg_scl_md_cnt['61-80']+res_lnl_avg_scl_md_cnt['0-20'])
    # res_lnl_avg_scl_md_cnt['21-40'] = res_lnl_avg_scl_md_cnt['21-40']*100/(res_lnl_avg_scl_md_cnt['21-40']+res_lnl_avg_scl_md_cnt['41-60']+res_lnl_avg_scl_md_cnt['61-80']+res_lnl_avg_scl_md_cnt['0-20'])
    # res_lnl_avg_scl_md_cnt['41-60'] = res_lnl_avg_scl_md_cnt['41-60']*100/(res_lnl_avg_scl_md_cnt['21-40']+res_lnl_avg_scl_md_cnt['41-60']+res_lnl_avg_scl_md_cnt['61-80']+res_lnl_avg_scl_md_cnt['0-20'])
    # res_lnl_avg_scl_md_cnt['61-80'] = res_lnl_avg_scl_md_cnt['61-80']*100/(res_lnl_avg_scl_md_cnt['21-40']+res_lnl_avg_scl_md_cnt['41-60']+res_lnl_avg_scl_md_cnt['61-80']+res_lnl_avg_scl_md_cnt['0-20'])
    plt.bar(res_lnl_avg_scl_md_cnt.keys(), res_lnl_avg_scl_md_cnt.values(), width=.3, color='blue')
    if(x==0):
      plt.title("introvert and {}-{} hour".format(2*(p-1),2*p))
    else:
      plt.title("Extrovert and {}-{} hour".format(2*(p-1),2*p))
    plt.xlabel("Loneliness Scale")
    plt.ylabel("Frequency")
# Out:
# {'0-20': 0, '21-40': 193, '41-60': 852, '61-80': 72}
# {'0-20': 0, '21-40': 20, '41-60': 68, '61-80': 6}
# {'0-20': 0, '21-40': 193, '41-60': 852, '61-80': 72}
# {'0-20': 0, '21-40': 106, '41-60': 455, '61-80': 38}
# {'0-20': 0, '21-40': 8, '41-60': 30, '61-80': 2}
# {'0-20': 0, '21-40': 106, '41-60': 455, '61-80': 38}
# {'0-20': 0, '21-40': 230, '41-60': 566, '61-80': 61}
# {'0-20': 0, '21-40': 18, '41-60': 36, '61-80': 4}
# {'0-20': 0, '21-40': 230, '41-60': 566, '61-80': 61}
# {'0-20': 0, '21-40': 14, '41-60': 175, '61-80': 16}
# {'0-20': 0, '21-40': 1, '41-60': 10, '61-80': 1}
# {'0-20': 0, '21-40': 14, '41-60': 175, '61-80': 16}
# {'0-20': 0, '21-40': 219, '41-60': 482, '61-80': 31}
# {'0-20': 0, '21-40': 22, '41-60': 36, '61-80': 2}
# {'0-20': 0, '21-40': 219, '41-60': 482, '61-80': 31}
# {'0-20': 0, '21-40': 35, '41-60': 121, '61-80': 0}
# {'0-20': 0, '21-40': 3, '41-60': 8, '61-80': 0}
# {'0-20': 0, '21-40': 35, '41-60': 121, '61-80': 0}
# ...
